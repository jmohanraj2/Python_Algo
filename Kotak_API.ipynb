# %%
pip install "git+https://github.com/Kotak-Neo/kotak-neo-api.git#egg=neo_api_client"
# Out:
# ...
#   Cloning https://github.com/Kotak-Neo/kotak-neo-api.git to c:\users\public\documents\wondershare\creatortemp\pip-install-xn_tndsr\neo-api-client_b5f80e327c844ad1a49b111ee00ff07f
#   Resolved https://github.com/Kotak-Neo/kotak-neo-api.git to commit f55fd944505a6ec99c66f1525142b115253da7bd
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached bidict-0.22.1-py3-none-any.whl (35 kB)
# ...
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached numpy-1.24.2-cp39-cp39-win_amd64.whl (14.9 MB)
# ...
#   Using cached pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached PyJWT-2.6.0-py3-none-any.whl (20 kB)
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# ...

# %%
import neo_api_client
from neo_api_client import NeoAPI

# %%
def on_message(message):
    print(message)
    
def on_error(error_message):
    print(error_message)
client = NeoAPI(consumer_key="GY7B4ibscmNgwU_HvrNjVDb6XnEa", consumer_secret="kxIhTc2ANXjl2ki9jWgLEb76XSka", 
                environment='prod', on_message=on_message, on_error=on_error, on_close=None, on_open=None)
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..KeenHa3-TgiQmTuViPewCcAEOrJC-hWIUYpq36EziZ4B6oaNIDk42mJxxOMiqLz5vRQ0AnRa5R8tK3KcAgm45Dpk7lfChlwEo-QmIL4PV16GSoUfbc2mZJUA0ruCa-iIp-TRBgqOZ3jLRXfXzCMiqxAig42pf8c1VJG1VuZu2Fq4-kqeT_MT2q6XRkko7Hjama512uEKHKJ_BHV4dVwJZVd5M0WiwOsNKQGZhI_xuVkB06ec6S7_rc71189TWmI-4Vp4q0WHvFXmMz6d7SAhUAxOw7cRgxqE6Dc-h0V7Q-om9XNDwbljA7eOTjumbU_591djb_ed3dUUbwUwqcQmDg
# ...

# %%
client.login(mobilenumber="+919642867935", password="Password-2")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..gy6fIx5NREjrggs3z4t9-HPKoGMbdq3YSL1t71Eg0Stotp2bJICz2wQaGAaX-nEQh9lZaRG0FNMgg_PZp8aYxd-eemqiopDQ1_steTuNFgTslvRCYi_kwwdaQhNIktMZ7-5TPbC9eu7kThbxfwqH7GvkRp6iZlz8ytqgn57ZRZLDIwJ8NtiDbnvpDWR00POgNCPdi16ZQFho6NnjyakW0CoATWSR0etmgvfcRGjQ7jLb1nGAUz3TbrKYksUoTKjzykpSmmuS0GD9iCZFaeo56TVGgnj3dl0b9nB3ioPTDsBejsq89WSbE_puKzrKwTFLFlNaNQC1RPS1B2iDX07TFg',
#   'sid': '57b5610e-db07-4a4c-928a-36b07a260174',
#   'rid': '47ab33d5-fdfd-4b7e-af96-8e8b255caee1',
#   'hsServerId': 'server5',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1698993689',
#    'lastUpdatedTS': '1698993689',
# ...

# %%
client.session_2fa(OTP="8006")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..mHUZV8IR4Lnl9oIyB3RcKPVInmCZSofWPbp8m2zloj3HkXzLe6qwICBJBEcFHKYLDftZliCiz7kkXh3NOnmNsjz5TKz57AVub8gJ7jvfQ_ZgEi8XGmMY3kjhohTHjJ2qljIEvgOY2YbsqgUgp8iEKnq0tX88SSZEh_tZFz-fWlwubaQsnRMvnXdYXCcW-BEDdTL3vTuCKYuZsQOV7ZoPBi3st0s_Kt1fktcIiLFlAWdqL3yuoRAhIb98NG-tO9GSy0sPfR75o3XjRVg_1u2wcFgrl53EbLk0Rt3_u4wW14jd8JUoFf7KjKEQxOlGE8LvOGDgyeItUfaCbxYBjG7Ucg',
#   'sid': '57b5610e-db07-4a4c-928a-36b07a260174',
#   'rid': '47ab33d5-fdfd-4b7e-af96-8e8b255caee1',
#   'hsServerId': 'server5',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1698993689',
#    'lastUpdatedTS': '1698993689',
# ...

# %%
client.trade_report()
# Out:
# {'stat': 'Not_Ok',
#  'errMsg': 'No Data',
#  'stCode': 5203,
#  'tid': 'server5_1808046'}

# %%
from neo_api_client import NeoAPI
def on_message(message):
    print(message)
    
def on_error(error_message):
    print(error_message)
    
#on_message, on_open, on_close and on_error is a call back function we will provide the response for the subscribe method.
# access_token is an optional one. If you have barrier token then pass and consumer_key and consumer_secret will be optional.
# environment by default uat you can pass prod to connect to live server
client = NeoAPI(consumer_key="eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..RbLYRmrhXW3LXAB7SNwnQdPF5AxL_BGNwEayGneYSlOco4S2VZooW6lpYzUI3j8f5iRhKoxd6OYWzL8_li32pc0r-Orr7FSRz_m8C4brxdWjw09IBBAteDDam6Mbd6DRNXP9TDI5hTKi0KSA84JEVpGp6EAYwNnxEJMR5Y9F9lw_nZKzj8KdprtmNRZuMHqE5awFUUdlhvPypx8JDlNkkQA62mJQTCNIoD3Oex-gSqXkV-jGKTw_4Ml9gbkFAC-zeYAUXqBNMBqql-NFr-ZYhEFmpF-UUXS9ev2qE7nz-1mgc8yMV96axvB9zsepmi-n089x6Z-AzuTwSoTIfPEQiQ", consumer_secret="", 
                environment='uat', on_message=on_message, on_error=on_error, on_close=None, on_open=None)

# Initiate login by passing any of the combinations mobilenumber & password (or) pan & password (or) userid & password
# Also this will generate the OTP to complete 2FA
client.login(mobilenumber="+919999999999", password="XXXX")

# Complete login and generate session token
client.session_2fa(OTP="")

# Once 2FA has you can place the order by using below function
client.place_order(exchange_segment='', product='', price='', order_type='', quantity=12, validity='', trading_symbol='',
                    transaction_type='', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)
						
# Modify an order
client.modify_order(order_id = "", price = 0, quantity = 1, disclosed_quantity = 0, trigger_price = 0, validity = "GFD")

# Cancel an order
client.cancel_order(order_id = "")

# This is delay type. if order id along with isVerify as True will be passed then check the status of the given order id and then proceed to further
client.cancel_order(order_id = "", isVerify=True)

# Get Order Book
client.order_report()

# Get Order History
client.order_history(order_id = "")

# Get Trade Book
client.trade_report()

# Get Detailed Trade Report for specific order id. 
client.trade_report(order_id = "")

# Get Positions
client.positions()

# Get Portfolio Holdings
client.holdings()

# Get Limits
client.limits(segment="", exchange="", product="")

# Get Margin required for Equity orders. 
client.margin_required(exchange_segment = "", price = "", order_type= "", product = "",   quantity = "", instrument_token = "",  transaction_type = "")

# Get Scrip Master CSV file
client.scrip_master()

# Get Scrip Master CSV file for specific Exchange Segment. 
client.scrip_master(exchange_segment = "")

# Search for the Scrip details from Scrip master file
# exchange_segment is mandatory option to pass and remaining parameters are optional
client.search_scrip(exchange_segment="cde_fo", symbol="", expiry="", option_type="",
                    strike_price="")

# Get Quote details. 
instrument_tokens = [{"instrument_token": "", "exchange_segment": ""},
    {"instrument_token": "", "exchange_segment": ""},
    {"instrument_token": "", "exchange_segment": ""},
    {"instrument_token": "", "exchange_segment": ""}]

# quote_type can be market_depth, ohlc, ltp, 52w, circuit_limits, scrip_details
# By Default quote_type is set as None that means you will get the complete data.
# Quotes api can be accessed without completing login by passing session_token, sid and server_id 
client.quotes(instrument_tokens = instrument_tokens, quote_type="", isIndex=False, 
              callback=on_message, session_token="", sid="",server_id="")

# Subscribe method will get you the live feed details of the given tokens.
# By Default isIndex is set as False and you want to get the live feed to index scrips set the isIndex flag as True 
# By Default isDepth is set as False and you want to get the depth information set the isDepth flag as True
client.subscribe(instrument_tokens = instrument_tokens, isIndex=False, isDepth=False)

# Un_Subscribes the given tokens. First the tokens will be checked weather that is subscribed. If not Subscribed we will send you the error message else we will unsubscribe the give tokens
client.un_subscribe(instrument_tokens=instrument_tokens)

#Order Feed 
client.subscribe_to_orderfeed()
#Terminate user's Session
client.logout()
# Out:
#   File "C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_22328\3156563779.py", line 1
#     sudo python setup.py install --user
#          ^
# SyntaxError: invalid syntax

# %%
client.scrip_master()
client.search_scrip(exchange_segment = "BFO", symbol = "NIFTY",  expiry = "30JUN2023", option_type = "PE", strike_price = "19100")
# Out:
# {'message': 'No data found with the given search information.Please try with other combinations.'}

# %%
# Get Positions
client.positions()
# Out:
# {'tid': 'server2_5771899',
#  'stat': 'Ok',
#  'stCode': 200,
#  'data': [{'buyAmt': '850.00',
#    'cfSellAmt': '0.00',
#    'prod': 'MIS',
#    'exSeg': 'nse_fo',
#    'sqrFlg': 'Y',
#    'actId': 'YVZZ0',
#    'cfBuyQty': '0',
#    'hsUpTm': '2023/11/21 14:45:55',
#    'cfSellQty': '0',
#    'tok': '46858',
#    'flBuyQty': '160',
#    'flSellQty': '160',
#    'sellAmt': '714.00',
#    'posFlg': 'true',
#    'cfBuyAmt': '0.00',
#    'stkPrc': '19500.00',
#    'trdSym': 'FINNIFTY23N2119500PE',
#    'sym': 'FINNIFTY',
#    'multiplier': '1',
#    'precision': '2',
#    'expDt': '21 Nov, 2023',
#    'type': 'OPTIDX',
#    'genNum': '1',
#    'series': 'XX',
#    'prcNum': '1',
#    'genDen': '1',
#    'brdLtQty': 40,
#    'exp': '1700577000',
#    'lotSz': '40',
#    'optTp': 'PE',
#    'prcDen': '1'}]}

# %%
postn =  {'tid': 'server2_5771899',
          'stat': 'Ok',
          'stCode': 200,
          'data': 
              [
                  {'buyAmt': '850.00',
                   'cfSellAmt': '0.00',
                   'prod': 'MIS',
                   'exSeg': 'nse_fo',
                   'sqrFlg': 'Y',
                   'actId': 'YVZZ0',
                   'cfBuyQty': '0',
                   'hsUpTm': '2023/11/21 14:45:55',
                   'cfSellQty': '0',
                   'tok': '46858',
                   'flBuyQty': '160',
                   'flSellQty': '160',
                   'sellAmt': '714.00',
                   'posFlg': 'true',
                   'cfBuyAmt': '0.00',
                   'stkPrc': '19500.00',
                   'trdSym': 'FINNIFTY23N2119500PE',
                   'sym': 'FINNIFTY',
                   'multiplier': '1',
                   'precision': '2',
                   'expDt': '21 Nov, 2023',
                   'type': 'OPTIDX',
                   'genNum': '1',
                   'series': 'XX',
                   'prcNum': '1',
                   'genDen': '1',
                   'brdLtQty': 40,
                   'exp': '1700577000',
                   'lotSz': '40',
                   'optTp': 'PE',
                   'prcDen': '1'}
                 ]
                     }
TRGR_PRICE = str(2.9*0.8)
SLP    = str(2.9*0.77)
SLPQTY = postn['data'][0]['flBuyQty'])
avg_trd_pricce = postn['data'][0]['buyAmt']/postn['data'][0]['flBuyQty']
if (postn['data'][0]['sqrFlg']) != "Y" and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce:
    if postn['data'][0]['trdSym'] = ord_rpt['data'][0]['trdSym'] and postn['data'][0]['prod'] = ord_rpt['data'][0]['prod']
            and postn['data'][0]['flBuyQty'] = ord_rpt['data'][0]['qty']:
        print("SL placed")
    else:
        
        print("order open")
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='SL', quantity=SLPQTY, validity='DAY', 
                       trading_symbol='BANKNIFTY23N2243900CE',
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGR_PRICE, tag=None)
else:
    print("order closed")

    
    
if (postn['data'][0]['sqrFlg']) != "Y" and inst_quo['message'][0]["last_traded_price"] > avg_trd_pricce:
    if postn['data'][0]['trdSym'] = ord_rpt['data'][0]['trdSym'] and postn['data'][0]['prod'] = ord_rpt['data'][0]['prod']
            and postn['data'][0]['flBuyQty'] = ord_rpt['data'][0]['qty'] and avg_trd_pricce < ord_rpt['data'][0]['avgPrc']:
        print("Profit order placed")
    else:
        
        print("order open")
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='L', quantity=SLPQTY, validity='DAY', 
                       trading_symbol='BANKNIFTY23N2243900CE',
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGT, tag=None)
    
    print("order closed")
# Out:
# order closed

# %%
# 4 Scenarios -- New 2nd Draft

pos_qty = postn['data'][0]['flBuyQty']
ord_qty = ord_rpt['data'][0]['qty']
SLPQTY  = pos_qty - ord_qty

# Place target order for all three quantites if LTP > AVG traded price
if postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] > avg_trd_pricce:
    TRGT_QTY = postn['data'][0]['flBuyQty']
    client.place_order(exchange_segment='NFO', product='MIS', price=TRGT, order_type='L', quantity=TRGT_QTY, validity='DAY', 
                       trading_symbol='BANKNIFTY23N2243900CE',
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price="0", tag=None)

# Check for SL order already placed - Else place a SL order upto 2nd Pramid
elif postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce 
        and SLPQTY1 ==postn['data'][0]['flBuyQty']:
        TRGT_QTY = postn['data'][0]['flBuyQty']
        ordr = client.order_report()
        if ordr['data'][0][''ordSt''] == 'open' and TRGT_QTY == SLPQTY1:
        print("Order already placed")
        pass
        else:
        ordr_id = ordr['data'][0]['exOrdId']
        trd_symbl = postn['data'][0]['trdSym']
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='SL', quantity=TRGT_QTY, validity='DAY', 
                       trading_symbol=trdSym,
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGR_PRICE, tag=None)

# Check for SL order already placed for Full quantity- Else Cancel 2nd Pramid SL order and  place a SL order upto Final Pramid
elif postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce 
        and QTY3 ==postn['data'][0]['flBuyQty']:
        TRGT_QTY = postn['data'][0]['flBuyQty']
        ordr = client.order_report()
        if ordr['data'][0][''ordSt''] == 'open' and TRGT_QTY == SLPQTY1:
        print("Order already placed")
        pass
        else:
        ordr_id = ordr['data'][0]['exOrdId']
        client.cancel_order(order_id =ordr_id )
        trd_symbl = postn['data'][0]['trdSym']
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='SL', quantity=TRGT_QTY, validity='DAY', 
                       trading_symbol=trdSym,
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGR_PRICE, tag=None)

    
else:
    print("order closed")

# %%
# TESTING of 4 Scenarios 

Qty    = 50
pricce = ltp
print("pricce",pricce)
price1 = str(pricce)
print("price1",price1)
Qty1   = str(Qty)
price2 = str(decimal_roundoff(round((float(pricce)*0.9),2)))
print("price2",price2)
print("Qty1",Qty1)
Qty2   = str(int(Qty1)*2)
price3 = str(decimal_roundoff(round((float(pricce)*0.8),2)))
print("price3",price3)
print("Qty2",Qty2)
Qty3   = str(int(Qty2)*2)
print("Qty3",Qty3)
TRGR_PRC = str(decimal_roundoff(float(pricce)*0.77))
SLP = str(decimal_roundoff(float(pricce)*0.75))
print("TRGR_PRC",TRGR_PRC)
print("SLP",SLP)
TRGT   = str(decimal_roundoff(float(pricce)*1.9))
print("TRGT",TRGT)
TQty = int(Qty1) + int(Qty2) + int(Qty3)
SLPQTY1 = int(Qty1) + int(Qty2)
#print(pricce,price1,price2,SLP)
print(TQty,SLPQTY1)


# Place target order for all three quantites if LTP > AVG traded price
if postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] > avg_trd_pricce:
    TRGT_QTY = postn['data'][0]['flBuyQty']
    #client.place_order starts
    price=TRGT
    quantity=TRGT_QTY
    trading_symbol=trd_symbl
    
# Check for SL order already placed - Else place a SL order upto 2nd Pramid
elif postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce 
        and SLPQTY1 ==postn['data'][0]['flBuyQty']:
        TRGT_QTY = postn['data'][0]['flBuyQty']
        #ordr = client.order_report()
        if ordr['data'][0][''ordSt''] == 'open' and TRGT_QTY == SLPQTY1:
            ordr_id = ordr['data'][0]['exOrdId']
            print("Order already placed")
        pass
        else:
             if ordr['data'][0][''ordSt''] == 'open':
                ordr_id = ordr['data'][0]['exOrdId']
                trd_symbl = postn['data'][0]['trdSym']
                #client.place_order starts
                price=SLP
                quantity=TRGT_QTY
                trading_symbol=trdSym
                trigger_price=TRGR_PRICE

# Check for SL order already placed for Full quantity- Else Cancel 2nd Pramid SL order and  place a SL order upto Final Pramid
elif postn['data'][0]['flSellQty'] == '0' and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce 
        and QTY3 ==postn['data'][0]['flBuyQty']:
        TRGT_QTY = postn['data'][0]['flBuyQty']
        #ordr = client.order_report()
        if ordr['data'][0][''ordSt''] == 'open' and TRGT_QTY == SLPQTY1:
        ordr_id = ordr['data'][0]['exOrdId']
        print("Order already placed")
        pass
        else:
            if ordr['data'][0][''ordSt''] == 'open':
                ordr_id = ordr['data'][0]['exOrdId']
                client.cancel_order(order_id =ordr_id )
                trd_symbl = postn['data'][0]['trdSym']
                client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='SL', quantity=TRGT_QTY, validity='DAY', 
                           trading_symbol=trdSym,
                            transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                            trigger_price=TRGR_PRICE, tag=None)

    
else:
    print("order closed")

# %%
ordr = {'tid': 'server5_4958091', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_MOB', 'sipInd': 'NA', 'prc': '16.40', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '608907', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '29-Nov-2023 14:10:15', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 150, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1700000143810854', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '30 Nov, 2023', 'trgPrc': '0.00', 'tok': '58278', 'symOrdId': 'NA', 'fldQty': 150, 'ordDtTm': '29-Nov-2023 14:10:17', 'avgPrc': '16.40', 'locId': '333333333333100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1701247215-860912-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '29-Nov-2023 14:10:17', 'hsUpTm': '2023/11/29 14:10:24', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'complete', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231129001775490', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1701247217, 'expDtSsb': '1701354600', 'dscQtyPct': '0', 'stkPrc': '43800.00', 'sym': 'BANKNIFTY', 'trdSym': 'BANKNIFTY23NOV43800PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '15', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '15', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_MOB', 'sipInd': 'NA', 'prc': '14.90', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '797630', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '29-Nov-2023 14:11:13', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 150, 'unFldSz': 150, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1700000144166519', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '30 Nov, 2023', 'trgPrc': '0.00', 'tok': '58278', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '29-Nov-2023 14:11:13', 'avgPrc': '0.00', 'locId': '333333333333100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1701247273-790702-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '29-Nov-2023 14:11:13', 'hsUpTm': '2023/11/29 14:11:13', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'open', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231129001779651', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1701247273, 'expDtSsb': '1701354600', 'dscQtyPct': '0', 'stkPrc': '43800.00', 'sym': 'BANKNIFTY', 'trdSym': 'BANKNIFTY23NOV43800PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '15', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '15', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_MOB', 'sipInd': 'NA', 'prc': '18.45', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '203730', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '29-Nov-2023 14:16:56', 'reqId': '2', 'algSeqNo': 'NA', 'qty': 150, 'unFldSz': 150, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1700000146203765', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '30 Nov, 2023', 'trgPrc': '0.00', 'tok': '58278', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '29-Nov-2023 14:16:56', 'avgPrc': '0.00', 'locId': '333333333333100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1701247616-197831-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '29-Nov-2023 14:16:56', 'hsUpTm': '2023/11/29 14:16:56', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'open', 'trnsTp': 'S', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231129001802014', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1701247616, 'expDtSsb': '1701354600', 'dscQtyPct': '0', 'stkPrc': '43800.00', 'sym': 'BANKNIFTY', 'trdSym': 'BANKNIFTY23NOV43800PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '15', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '15', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}]}
postn = {'tid': 'server5_4998918', 'stat': 'Ok', 'stCode': 200, 'data': [{'buyAmt': '2460.00', 'cfSellAmt': '0.00', 'prod': 'MIS', 'exSeg': 'nse_fo', 'sqrFlg': 'Y', 'actId': 'YVZZ0', 'cfBuyQty': '0', 'hsUpTm': '2023/11/29 14:10:17', 'cfSellQty': '0', 'tok': '58278', 'flBuyQty': '150', 'flSellQty': '0', 'sellAmt': '0.00', 'posFlg': 'true', 'cfBuyAmt': '0.00', 'stkPrc': '43800.00', 'trdSym': 'BANKNIFTY23NOV43800PE', 'sym': 'BANKNIFTY', 'multiplier': '1', 'precision': '2', 'expDt': '30 Nov, 2023', 'type': 'OPTIDX', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': 15, 'exp': '1701354600', 'lotSz': '15', 'optTp': 'PE', 'prcDen': '1'}]}
inst_quo = {'message': [{'last_traded_time': '23/11/2023 11:05:53', 'volume': '73655050', 'last_traded_price': '0.55', 'last_traded_quantity': '50', 'total_buy_quantity': '27961950', 'total_sell_quantity': '1697000', 'buy_price': '0.55', 'sell_price': '0.60', 'buy_quantity': '1482050', 'average_price': '0.63', 'lower_circuit_limit': '0.05', 'upper_circuit_limit': '11.70', '52week_high': '21474836.48', '52week_low': '21474836.48', 'open_interest': '18086400', 'multiplier': '1', 'precision': '2', 'change': '-1.10', 'net_change_percentage': '-66.67', 'total_traded_value': '46402681.50', 'instrument_token': '48241', 'exchange_segment': 'nse_fo', 'trading_symbol': 'NIFTY23N2319500PE', 'ohlc': {'open': '0.80', 'high': '0.80', 'low': '0.50', 'close': '1.65'}}]}

# %%
pos_qty = postn['data'][0]['flBuyQty']
ord_qty = ord_rpt['data'][0]['qty']
SLPQTY  = pos_qty - ord_qty
if (postn['data'][0]['sqrFlg']) != "Y" and inst_quo['message'][0]["last_traded_price"] < avg_trd_pricce and :
    if postn['data'][0]['trdSym'] = ord_rpt['data'][0]['trdSym'] and postn['data'][0]['prod'] = ord_rpt['data'][0]['prod']
            and postn['data'][0]['flBuyQty'] = ord_rpt['data'][0]['qty']:
        print("SL placed")
    else:
        
        print("order open")
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='SL', quantity=SLPQTY, validity='DAY', 
                       trading_symbol='BANKNIFTY23N2243900CE',
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGR_PRC, tag=None)
else:
    print("order closed")

    
    
if (postn['data'][0]['sqrFlg']) != "Y" and inst_quo['message'][0]["last_traded_price"] > avg_trd_pricce:
    if postn['data'][0]['trdSym'] = ord_rpt['data'][0]['trdSym'] and postn['data'][0]['prod'] = ord_rpt['data'][0]['prod']
            and postn['data'][0]['flBuyQty'] = ord_rpt['data'][0]['qty'] and avg_trd_pricce < ord_rpt['data'][0]['avgPrc']:
        print("Profit order placed")
    else:
        
        print("order open")
        client.place_order(exchange_segment='NFO', product='MIS', price=SLP, order_type='L', quantity=SLPQTY, validity='DAY', 
                       trading_symbol='BANKNIFTY23N2243900CE',
                        transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                        trigger_price=TRGT, tag=None)
    
    print("order closed")

# %%
ord_rpt = client.order_report()
filtered_list = [stat for stat in ord_rpt['data'][0]['ordSt'] if stat in "pending"]
ord_stat = ord_rpt['data'][0]['ordSt']
token =  ord_rpt['data'][0]['tok']
trade_inst = ord_rpt['data'][0]['trdSym']

# %%
#29Nov2023
ord_rpt = client.order_report()
print(ord_rpt)
# Out:
# {'tid': 'server5_4958091', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_MOB', 'sipInd': 'NA', 'prc': '16.40', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '608907', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '29-Nov-2023 14:10:15', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 150, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1700000143810854', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '30 Nov, 2023', 'trgPrc': '0.00', 'tok': '58278', 'symOrdId': 'NA', 'fldQty': 150, 'ordDtTm': '29-Nov-2023 14:10:17', 'avgPrc': '16.40', 'locId': '333333333333100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1701247215-860912-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '29-Nov-2023 14:10:17', 'hsUpTm': '2023/11/29 14:10:24', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'complete', 'trnsTp':
# ...

# %%
trade_inst = [{"instrument_token": "48241", "exchange_segment": "nse_fo"}]
inst_quo = client.quotes(instrument_tokens=trade_inst, quote_type="", isIndex=False)
    
#inst_quo = client.quotes(instrument_tokens = trade_inst, exchange_segment = "nse_fo", isIndex=False, session_token="", sid="", server_id="")
ltp = inst_quo['message'][0]["last_traded_price"]
print(ltp)
print(inst_quo)
# Out:
# 0.55
# {'message': [{'last_traded_time': '23/11/2023 11:05:53', 'volume': '73655050', 'last_traded_price': '0.55', 'last_traded_quantity': '50', 'total_buy_quantity': '27961950', 'total_sell_quantity': '1697000', 'buy_price': '0.55', 'sell_price': '0.60', 'buy_quantity': '1482050', 'average_price': '0.63', 'lower_circuit_limit': '0.05', 'upper_circuit_limit': '11.70', '52week_high': '21474836.48', '52week_low': '21474836.48', 'open_interest': '18086400', 'multiplier': '1', 'precision': '2', 'change': '-1.10', 'net_change_percentage': '-66.67', 'total_traded_value': '46402681.50', 'instrument_token': '48241', 'exchange_segment': 'nse_fo', 'trading_symbol': 'NIFTY23N2319500PE', 'ohlc': {'open': '0.80', 'high': '0.80', 'low': '0.50', 'close': '1.65'}}]}

# %%
client.order_report()
# Out:
# {'tid': 'server3_3964705',
#  'stat': 'Ok',
#  'stCode': 200,
#  'data': [{'brkClnt': '08081',
#    'ordValDt': 'NA',
#    'exUsrInfo': 'NA',
#    'mfdBy': 'NA',
#    'vendorCode': '',
#    'rmk': '--',
#    'odCrt': 'NA',
#    'ordSrc': 'ADMINCPPAPI_MOB',
#    'sipInd': 'NA',
#    'prc': '4.00',
#    'prcTp': 'L',
#    'cnlQty': 0,
#    'uSec': '642029',
#    'classification': '0',
#    'mktPro': '0.00',
#    'ordEntTm': '16-Nov-2023 12:53:01',
#    'reqId': '1',
#    'algSeqNo': 'NA',
#    'qty': 50,
#    'unFldSz': 0,
#    'mktProPct': '--',
#    'algCat': 'NA',
#    'exOrdId': '1000000177513850',
#    'dscQty': 0,
#    'actId': 'YVZZ0',
#    'expDt': '16 Nov, 2023',
#    'trgPrc': '0.00',
#    'tok': '40081',
#    'symOrdId': 'NA',
#    'fldQty': 50,
#    'ordDtTm': '16-Nov-2023 12:53:01',
#    'avgPrc': '3.85',
#    'locId': '333333333333100',
#    'algId': 'NA',
#    'stat': 'Ok',
#    'prod': 'MIS',
#    'exSeg': 'nse_fo',
# ...

# %%
all_ordr =  {'tid': 'server3_3964705',
             'stat': 'Ok',
             'stCode': 200,
             'data': [{'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '4.00',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '642029',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 12:53:01',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1000000177513850',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40081',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 12:53:01',
               'avgPrc': '3.85',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700119381-635193-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 12:53:01',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116001530765',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700119381,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19850.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619850CE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'CE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '2.80',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '091375',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 11:08:47',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1100000099051609',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40068',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 11:08:47',
               'avgPrc': '2.75',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700113127-84697-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 11:08:47',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000918154',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700113127,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19650.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619650PE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'PE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'AKLPY0424H',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '2.70',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '696953',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 11:19:38',
               'reqId': '7',
               'algSeqNo': 'NA',
               'qty': 150,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1100000070755834',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40068',
               'symOrdId': 'NA',
               'fldQty': 150,
               'ordDtTm': '16-Nov-2023 11:20:46',
               'avgPrc': '2.70',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700113778-691889-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 11:20:46',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'S',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000655745',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700113846,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19650.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619650PE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'PE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '5.45',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '979359',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 10:11:45',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1100000061686017',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40068',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 10:15:51',
               'avgPrc': '5.45',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700109705-32900-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 10:15:51',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000562416',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700109951,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19650.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619650PE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'PE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '6.15',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '457703',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 10:11:15',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1100000061385946',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40068',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 10:11:19',
               'avgPrc': '6.15',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700109675-205943-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 10:11:19',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000559195',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700109679,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19650.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619650PE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'PE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '12.90',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '899685',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 09:29:21',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1000000014669665',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40069',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 09:37:46',
               'avgPrc': '12.90',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700107161-124716-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 09:37:46',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'S',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000184969',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700107666,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19700.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619700CE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'CE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'NA',
               'vendorCode': '',
               'rmk': '--',
             'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '8.20',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '897145',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 09:19:38',
               'reqId': '1',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1000000005557248',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40069',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 09:20:49',
               'avgPrc': '8.20',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700106578-148268-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 09:20:49',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000089583',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700106649,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19700.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619700CE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'CE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'AKLPY0424H',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '4.70',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '218292',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 09:17:54',
               'reqId': '6',
               'algSeqNo': 'NA',
               'qty': 100,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1100000000499650',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40026',
               'symOrdId': 'NA',
               'fldQty': 100,
               'ordDtTm': '16-Nov-2023 09:17:57',
               'avgPrc': '4.70',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'NRML',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700106474-939835-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 09:17:57',
               'hsUpTm': '2023/11/16 12:53:03',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'S',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116000030788',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700106477,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19550.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619550PE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'PE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'AKLPY0424H',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '4.20',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '915307',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 12:57:06',
               'reqId': '3',
               'algSeqNo': 'NA',
               'qty': 50,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1000000177664425',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40081',
               'symOrdId': 'NA',
               'fldQty': 50,
               'ordDtTm': '16-Nov-2023 12:58:08',
               'avgPrc': '4.20',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700119626-730064-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 12:58:08',
               'hsUpTm': '2023/11/16 12:58:08',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'B',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116001532198',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700119688,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19850.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619850CE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'CE',
               'prcDen': '1'},
              {'brkClnt': '08081',
               'ordValDt': 'NA',
               'exUsrInfo': 'NA',
               'mfdBy': 'AKLPY0424H',
               'vendorCode': '',
               'rmk': '--',
               'odCrt': 'NA',
               'ordSrc': 'ADMINCPPAPI_MOB',
               'sipInd': 'NA',
               'prc': '5.45',
               'prcTp': 'L',
               'cnlQty': 0,
               'uSec': '684240',
               'classification': '0',
               'mktPro': '0.00',
               'ordEntTm': '16-Nov-2023 12:58:22',
               'reqId': '2',
               'algSeqNo': 'NA',
               'qty': 100,
               'unFldSz': 0,
               'mktProPct': '--',
               'algCat': 'NA',
               'exOrdId': '1000000178795516',
               'dscQty': 0,
               'actId': 'YVZZ0',
               'expDt': '16 Nov, 2023',
               'trgPrc': '0.00',
               'tok': '40081',
               'symOrdId': 'NA',
               'fldQty': 100,
               'ordDtTm': '16-Nov-2023 12:59:53',
               'avgPrc': '5.45',
               'locId': '333333333333100',
               'algId': 'NA',
               'stat': 'Ok',
               'prod': 'MIS',
               'exSeg': 'nse_fo',
               'GuiOrdId': '1700119702-126856-AKLPY0424H-ADMINAPI',
               'usrId': 'AKLPY0424H',
               'rptTp': 'NA',
               'exCfmTm': '16-Nov-2023 12:59:53',
               'hsUpTm': '2023/11/16 12:59:53',
               'ordGenTp': 'NA',
               'vldt': 'DAY',
               'tckSz': '0.05',
               'ordSt': 'complete',
               'trnsTp': 'S',
               'refLmtPrc': 0.0,
               'coPct': 0.0,
               'nOrdNo': '231116001541749',
               'ordAutSt': 'NA',
               'rejRsn': '--',
               'boeSec': 1700119793,
               'expDtSsb': '1700145000',
               'dscQtyPct': '0',
               'stkPrc': '19850.00',
               'sym': 'NIFTY',
               'trdSym': 'NIFTY23N1619850CE',
               'multiplier': '1',
               'precision': '2',
               'noMktProFlg': '0.00',
               'genNum': '1',
               'series': 'XX',
               'prcNum': '1',
               'genDen': '1',
               'brdLtQty': '50',
               'mktProFlg': '0.00',
               'defMktProV': '0.00',
               'lotSz': '50',
               'minQty': 0,
               'optTp': 'CE',
               'prcDen': '1'}]}

# %%
#statok = all_ordr['data'][]['exOrdId']
#print(statok)
import pandas as pd

ordr_list = [all_ordr['data'] for ordrs in all_ordr['data']]
df = pd.DataFrame(ordr_list)
print(df)
# Out:
#                                                    0
# 0  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...  \
# 1  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 2  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 3  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 4  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 5  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 6  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 7  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 8  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 9  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
#
#                                                    1
# 0  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...  \
# 1  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 2  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 3  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 4  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# 5  {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrI...
# ...

# %%
from neo_api_client import NeoAPI
def on_message(message):
    print(message)
    
def on_error(error_message):
    print(error_message)
    
client = NeoAPI(consumer_key="eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..RbLYRmrhXW3LXAB7SNwnQdPF5AxL_BGNwEayGneYSlOco4S2VZooW6lpYzUI3j8f5iRhKoxd6OYWzL8_li32pc0r-Orr7FSRz_m8C4brxdWjw09IBBAteDDam6Mbd6DRNXP9TDI5hTKi0KSA84JEVpGp6EAYwNnxEJMR5Y9F9lw_nZKzj8KdprtmNRZuMHqE5awFUUdlhvPypx8JDlNkkQA62mJQTCNIoD3Oex-gSqXkV-jGKTw_4Ml9gbkFAC-zeYAUXqBNMBqql-NFr-ZYhEFmpF-UUXS9ev2qE7nz-1mgc8yMV96axvB9zsepmi-n089x6Z-AzuTwSoTIfPEQiQ", consumer_secret="", 
                environment='uat', on_message=on_message, on_error=on_error, on_close=None, on_open=None)

# %%
Qty    = 50
pricce = ltp
print("pricce",pricce)
price1 = str(pricce)
print("price1",price1)
Qty1   = str(Qty)
price2 = str(decimal_roundoff(round((float(pricce)*0.9),2)))
print("price2",price2)
print("Qty1",Qty1)
Qty2   = str(int(Qty1)*2)
price3 = str(decimal_roundoff(round((float(pricce)*0.8),2)))
print("price3",price3)
print("Qty2",Qty2)
Qty3   = str(int(Qty2)*2)
print("Qty3",Qty3)
TRGR_PRC = str(decimal_roundoff(float(pricce)*0.77))
SLP = str(decimal_roundoff(float(pricce)*0.75))
print("TRGR_PRC",TRGR_PRC)
print("SLP",SLP)
TRGT   = str(decimal_roundoff(float(pricce)*1.9))
print("TRGT",TRGT)
TQty = int(Qty1) + int(Qty2) + int(Qty3)
SLPQTY1 = int(Qty1) + int(Qty2)
#print(pricce,price1,price2,SLP)
print(TQty,SLPQTY1)
# Out:
# pricce 19.7
# price1 19.7
# price2 17.75
# Qty1 50
# price3 15.75
# Qty2 100
# Qty3 200
# TRGR_PRC 15.15
# SLP 14.75
# TRGT 37.45
# 350 150

# %%
def decimal_roundoff(decimal):
    decimal = "{:.2f}".format(decimal)
    #print("decimall",decimal)
    nw_decimal = 9.9
    ss1 = str(decimal)
    dott = ss1.find(".")
    strt = dott +2
    end = strt +2
    strt1 = dott +1
    end1 = strt1 + 2
    #print(dott,strt,strt1)
    ss4 = ss1[strt:end]
    #print("ss4",ss4)
    if ss4 == " ":
        ss2 = 0
    else:
        ss2 = int(ss1[strt:end])
   # if ss2 == " ":
   #     ss2 = 0
    ss3 = int(ss1[strt1:end1])
    #print(ss2)
    #print("ss3",ss3)
    if ss2 == 1 or ss2 == 2:
        #print("12")
        nw_decimal = ss1[:-1] + '0'
        return nw_decimal

        #print("nw_decimal12",nw_decimal12)
    elif ss2 == 3 or ss2 == 4 or ss2 == 6 or ss2 == 7:
        #print("3, 4, 6, 7")
        #lldigi = 5
        nw_decimal = ss1[:-1] + '5'
        return nw_decimal
        #print("nw_decimal2467",nw_decimal2467)
    elif ss2 == 8 or ss2 == 9:
        if ss2 == 8:
            nw_decimal = float(ss1) + 0.02
            return nw_decimal
        elif ss2 == 9:
            nw_decimal = float(ss1) + 0.01
            return nw_decimal
    else:
        nw_decimal = decimal
        return nw_decimal
        #print("nw_decimal89",nw_decimal89)
    

#nw = decimal_roundoff(ltp)
#print(nw)
    #print(nw_decimal)

# %%
import math

number = 3.14159
rounded_up = math.ceil(number)
rounded_down = math.floor(number)
truncated = math.trunc(number)
print("rounded_up",rounded_up)
print("rounded_down",rounded_down)
print("truncated",truncated)

from decimal import Decimal, ROUND_HALF_UP

original_number1 = 3.72
original_number2 = 3.44
rounded_decimal1 = Decimal(original_number1).quantize(Decimal('0.05'), rounding=ROUND_HALF_UP)
rounded_decimal2 = Decimal(original_number2).quantize(Decimal('0.05'), rounding=ROUND_HALF_UP)
print("rounded_decimal1",rounded_decimal1)
print("rounded_decimal2",rounded_decimal2)

def round_to_nearest_half(number):
    return round(number * 2) / 2

original_number3 = round_to_nearest_half(0.44)

print(original_number3)

from decimal import Decimal, ROUND_CEILING

from decimal import Decimal, ROUND_UP

number = 0.44
rounded_number = Decimal(str(number)).quantize(Decimal('0.05'), rounding=ROUND_UP)

print("round_number",rounded_number)

from decimal import Decimal, ROUND_HALF_UP

decimal_number = Decimal('3.14159')
rounded_decimal = decimal_number.quantize(Decimal('0.01'), rounding=ROUND_FLOOR)
print("roun_number",rounded_decimal)
# Out:
# rounded_up 4
# rounded_down 3
# truncated 3
# rounded_decimal1 3.72
# rounded_decimal2 3.44
# 0.5
# round_number 0.44
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_23048\1761018871.py in <module>
#      37
#      38 decimal_number = Decimal('3.14159')
# ---> 39 rounded_decimal = decimal_number.quantize(Decimal('0.01'), rounding=ROUND_FLOOR)
#      40 print("roun_number",rounded_decimal)
#
# NameError: name 'ROUND_FLOOR' is not defined

# %%
Qty    = 50
pricce = 10
price1 = str(pricce)
Qty1   = str(Qty)
price2 = str(pricce*0.9)
Qty2   = str(Qty1*2)
price3 = str(pricce*0.8)
Qty3   = str(Qty2*2)
SLP    = str(pricce*0.77)
print(pricce,price1,price2,SLP)
client.place_order(exchange_segment='NFO', product='MIS', price=price1, order_type='L', quantity=Qty1, validity='DAY', 
                   trading_symbol='BANKNIFTY23N2243900CE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price2, order_type='L', quantity=Qty2, validity='DAY', 
                   trading_symbol='BANKNIFTY23N2243900CE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price3, order_type='L', quantity=Qty3, validity='DAY', 
                   trading_symbol='BANKNIFTY23N2243900CE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

# %%
Qty    = 50
pricce = 1.3
price1 = str(pricce)
Qty1   = str(Qty)
price2 = str(round(((pricce*0.9*2)/2),1))
Qty2   = str(Qty*2)
price3 = str(round(((pricce*0.8*2)/2),1))
Qty3   = str(Qty*4)
SLP    = str((round((pricce*0.77*2)/2),1))
print(price1, price2, price3, Qty1,Qty2,Qty3)
round(((pricce*0.9*2)/2),2)

client.place_order(exchange_segment='NFO', product='MIS', price=price1, order_type='L', quantity=Qty1, validity='DAY', 
                   trading_symbol='NIFTY23N1619700PE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price2, order_type='L', quantity=Qty2, validity='DAY', 
                   trading_symbol='NIFTY23N1619700PE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price3, order_type='L', quantity=Qty3, validity='DAY', 
                   trading_symbol='NIFTY23N1619700PE',
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)
# Out:
# 1.3 1.2 1.0 50 100 200
# {'stat': 'Ok',
#  'nOrdNo': '231116001723176',
#  'tid': 'server3_4412889',
#  'stCode': 200}

# %%
trade_inst = [{"instrument_token": "42495", "exchange_segment": "nse_fo"}]
inst_quo = client.quotes(instrument_tokens=trade_inst, quote_type="", isIndex=False)
trading_sym = inst_quo['message'][0]["trading_symbol"]
#inst_quo = client.quotes(instrument_tokens = trade_inst, exchange_segment = "nse_fo", isIndex=False, session_token="", sid="", server_id="")
ltp = inst_quo['message'][0]["last_traded_price"]

#ltp = '12.49'
Qty    = 40
pricce = ltp
print("pricce",pricce)
price1 = str(pricce)
print("price1",price1)
Qty1   = str(Qty)
price2 = str(decimal_roundoff(round((float(pricce)*0.9),2)))
print("price2",price2)
print("Qty1",Qty1)
Qty2   = str(int(Qty1)*2)
price3 = str(decimal_roundoff(round((float(pricce)*0.8),2)))
print("price3",price3)
print("Qty2",Qty2)
Qty3   = str(int(Qty2)*2)
print("Qty3",Qty3)
TRGR_PRC = str(decimal_roundoff(float(pricce)*0.77))
SLP = str(decimal_roundoff(float(pricce)*0.75))
print("TRGR_PRC",TRGR_PRC)
print("SLP",SLP)
TRGT   = str(decimal_roundoff(float(pricce)*1.9))
print("TRGT",TRGT)
TQty = int(Qty1) + int(Qty2) + int(Qty3)
SLPQTY1 = int(Qty1) + int(Qty2)
#print(pricce,price1,price2,SLP)
print(TQty,SLPQTY1)

client.place_order(exchange_segment='NFO', product='MIS', price=price1, order_type='L', quantity=Qty1, validity='DAY', 
                   trading_symbol=trading_sym,
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price2, order_type='L', quantity=Qty2, validity='DAY', 
                   trading_symbol=trading_sym,
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)

client.place_order(exchange_segment='NFO', product='MIS', price=price3, order_type='L', quantity=Qty3, validity='DAY', 
                   trading_symbol=trading_sym,
                    transaction_type='B', amo="NO", disclosed_quantity="0", market_protection="0", pf="N",
                    trigger_price="0", tag=None)
# Out:
# pricce 1.90
# price1 1.90
# price2 1.70
# Qty1 40
# price3 1.50
# Qty2 80
# Qty3 160
# TRGR_PRC 1.45
# SLP 1.40
# TRGT 3.60
# 280 120
# {'stat': 'Ok',
#  'nOrdNo': '231124001482182',
#  'tid': 'server5_4105238',
#  'stCode': 200}

# %%
trade_inst = [{"instrument_token": "42481", "exchange_segment": "nse_fo"}]
inst_quo = client.quotes(instrument_tokens=trade_inst, quote_type="", isIndex=False)
    
#inst_quo = client.quotes(instrument_tokens = trade_inst, exchange_segment = "nse_fo", isIndex=False, session_token="", sid="", server_id="")
ltp = inst_quo['message'][0]["last_traded_price"]
print(ltp,inst_quo)
# Out:
# 1.10 {'message': [{'last_traded_time': '24/11/2023 14:10:04', 'volume': '9484600', 'last_traded_price': '1.10', 'last_traded_quantity': '40', 'total_buy_quantity': '449680', 'total_sell_quantity': '156320', 'buy_price': '1.05', 'sell_price': '1.10', 'buy_quantity': '24680', 'average_price': '1.70', 'lower_circuit_limit': '0.05', 'upper_circuit_limit': '106.75', '52week_high': '21474836.48', '52week_low': '21474836.48', 'open_interest': '1527560', 'multiplier': '1', 'precision': '2', 'change': '-1.75', 'net_change_percentage': '-61.40', 'total_traded_value': '16123820.00', 'instrument_token': '42481', 'exchange_segment': 'nse_fo', 'trading_symbol': 'FINNIFTY23NOV19200PE', 'ohlc': {'open': '2.05', 'high': '2.85', 'low': '1.05', 'close': '2.85'}}]}

# %%
# Order Report before Closing/cancelling
ordr_rpot = client.order_report()
#filteredd_list = [stat for stat in ord_rpt['data'][0]['ordSt'] if stat in "pending"]
#ord_stats = ord_rpt['data'][0]['ordSt']
#tokenn =  ord_rpt['data'][0]['tok']
#tradde_inst = ord_rpt['data'][0]['trdSym']

# %%
print(ordr_rpot)
# Out:
# {'tid': 'server5_4149474', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.50', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '638175', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:15:10', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 160, 'unFldSz': 160, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000068166797', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:15:10', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815510-630460-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:15:10', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'open', 'trnsTp': 
# ...

# %%
import json
json_form = json.dumps(ordr_rpot, indent = 4)
print(json_form)
# Out:
# {
#     "tid": "server5_4233232",
#     "stat": "Ok",
#     "stCode": 200,
#     "data": [
#         {
#             "brkClnt": "08081",
#             "ordValDt": "NA",
#             "exUsrInfo": "NA",
#             "mfdBy": "AKLPY0424H",
#             "vendorCode": "",
#             "rmk": "--",
#             "odCrt": "NA",
#             "ordSrc": "ADMINCPPAPI_TRADEAPI",
#             "sipInd": "NA",
#             "prc": "1.50",
#             "prcTp": "L",
#             "cnlQty": 160,
#             "uSec": "023246",
#             "classification": "0",
#             "mktPro": "0.00",
#             "ordEntTm": "24-Nov-2023 14:15:10",
#             "reqId": "1",
#             "algSeqNo": "NA",
#             "qty": 160,
#             "unFldSz": 160,
#             "mktProPct": "--",
#             "algCat": "NA",
#             "exOrdId": "1900000068166797",
#             "dscQty": 0,
#             "actId": "YVZZ0",
#             "expDt": "28 Nov, 2023",
#             "trgPrc": "0.00",
# ...

# %%
ordrr_rpt_after_closing = {'tid': 'server5_4239364', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.50', 'prcTp': 'L', 'cnlQty': 160, 'uSec': '023246', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:15:10', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 160, 'unFldSz': 160, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000068166797', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:22:52', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815510-630460-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:22:52', 'hsUpTm': '2023/11/24 14:22:52', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancelled', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001482182', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815972, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19300.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19300PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.70', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '516340', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:15:10', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 80, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000068165805', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 80, 'ordDtTm': '24-Nov-2023 14:18:37', 'avgPrc': '1.70', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815510-303351-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:18:37', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'complete', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001482167', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815717, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19300.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19300PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.90', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '957525', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:15:09', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 40, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000068164841', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 40, 'ordDtTm': '24-Nov-2023 14:18:20', 'avgPrc': '1.90', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815509-952797-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:18:20', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'complete', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001482145', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815700, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19300.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19300PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '0.85', 'prcTp': 'L', 'cnlQty': 160, 'uSec': '502160', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:54', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 160, 'unFldSz': 160, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067779241', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:15:01', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815374-24295-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:15:01', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancelled', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001474078', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815501, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '0.95', 'prcTp': 'L', 'cnlQty': 80, 'uSec': '116415', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:53', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 80, 'unFldSz': 80, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067778650', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:15:06', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815373-722928-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:15:06', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancelled', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001474064', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815506, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.05', 'prcTp': 'L', 'cnlQty': 40, 'uSec': '127941', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:53', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 40, 'unFldSz': 40, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067778073', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:14:57', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815373-413812-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:14:57', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancelled', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001474041', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815497, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '0.90', 'prcTp': 'L', 'cnlQty': 200, 'uSec': '074421', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:28', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 200, 'unFldSz': 200, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067719294', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:13:11', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815348-749809-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:13:11', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancelled', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001472461', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815391, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '--', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.00', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '450286', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:28', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 100, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067718432', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:12:28', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815348-442759-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': 'NA', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'rejected', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001472433', 'ordAutSt': 'NA', 'rejRsn': '16328 : Quantity is not a multiple of regular lot', 'boeSec': 1700815348, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '--', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.10', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '108329', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:12:28', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 50, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000067717624', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42481', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:12:28', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815348-100496-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': 'NA', 'hsUpTm': '2023/11/24 14:18:49', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'rejected', 'trnsTp': 'B', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001472398', 'ordAutSt': 'NA', 'rejRsn': '16328 : Quantity is not a multiple of regular lot', 'boeSec': 1700815348, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19200.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19200PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}, {'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'NA', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_MOB', 'sipInd': 'NA', 'prc': '1.70', 'prcTp': 'L', 'cnlQty': 0, 'uSec': '514518', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:22:45', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 120, 'unFldSz': 0, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000070049761', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 120, 'ordDtTm': '24-Nov-2023 14:22:45', 'avgPrc': '1.70', 'locId': '333333333333100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815965-507160-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:22:45', 'hsUpTm': '2023/11/24 14:22:45', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'complete', 'trnsTp': 'S', 'refLmtPrc': 0.0, 'coPct': 0.0, 'nOrdNo': '231124001522117', 'ordAutSt': 'NA', 'rejRsn': '--', 'boeSec': 1700815965, 'expDtSsb': '1701181800', 'dscQtyPct': '0', 'stkPrc': '19300.00', 'sym': 'FINNIFTY', 'trdSym': 'FINNIFTY23NOV19300PE', 'multiplier': '1', 'precision': '2', 'noMktProFlg': '0.00', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': '40', 'mktProFlg': '0.00', 'defMktProV': '0.00', 'lotSz': '40', 'minQty': 0, 'optTp': 'PE', 'prcDen': '1'}]}
import json

ordr_after_cls = json.dumps(ordrr_rpt_after_closing , indent = 4) 
print(ordr_after_cls)
# Out:
# {
#     "tid": "server5_4239364",
#     "stat": "Ok",
#     "stCode": 200,
#     "data": [
#         {
#             "brkClnt": "08081",
#             "ordValDt": "NA",
#             "exUsrInfo": "NA",
#             "mfdBy": "AKLPY0424H",
#             "vendorCode": "",
#             "rmk": "--",
#             "odCrt": "NA",
#             "ordSrc": "ADMINCPPAPI_TRADEAPI",
#             "sipInd": "NA",
#             "prc": "1.50",
#             "prcTp": "L",
#             "cnlQty": 160,
#             "uSec": "023246",
#             "classification": "0",
#             "mktPro": "0.00",
#             "ordEntTm": "24-Nov-2023 14:15:10",
#             "reqId": "1",
#             "algSeqNo": "NA",
#             "qty": 160,
#             "unFldSz": 160,
#             "mktProPct": "--",
#             "algCat": "NA",
#             "exOrdId": "1900000068166797",
#             "dscQty": 0,
#             "actId": "YVZZ0",
#             "expDt": "28 Nov, 2023",
#             "trgPrc": "0.00",
# ...

# %%
client.holdings()
# Out:
# {'data': []}

# %%
client.quotes(instrument_tokens = instrument_tokens, quote_type="", isIndex=False, 
              callback=on_message, session_token="", sid="",server_id="")

# %%
# Position before Closing
pos_report = client.positions()
print(pos_report)
# Out:
# {'tid': 'server5_4159353', 'stat': 'Ok', 'stCode': 200, 'data': [{'buyAmt': '212.00', 'cfSellAmt': '0.00', 'prod': 'MIS', 'exSeg': 'nse_fo', 'sqrFlg': 'Y', 'actId': 'YVZZ0', 'cfBuyQty': '0', 'hsUpTm': '2023/11/24 14:19:13', 'cfSellQty': '0', 'tok': '42495', 'flBuyQty': '120', 'flSellQty': '0', 'sellAmt': '0.00', 'posFlg': 'true', 'cfBuyAmt': '0.00', 'stkPrc': '19300.00', 'trdSym': 'FINNIFTY23NOV19300PE', 'sym': 'FINNIFTY', 'multiplier': '1', 'precision': '2', 'expDt': '28 Nov, 2023', 'type': 'OPTIDX', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': 40, 'exp': '1701181800', 'lotSz': '40', 'optTp': 'PE', 'prcDen': '1'}]}

# %%
# Order Report After Closing/cancelling
ordr_rpott = client.order_report()
print(ordr_rpott)
# Out:
# {'tid': 'server5_4239364', 'stat': 'Ok', 'stCode': 200, 'data': [{'brkClnt': '08081', 'ordValDt': 'NA', 'exUsrInfo': 'NA', 'mfdBy': 'AKLPY0424H', 'vendorCode': '', 'rmk': '--', 'odCrt': 'NA', 'ordSrc': 'ADMINCPPAPI_TRADEAPI', 'sipInd': 'NA', 'prc': '1.50', 'prcTp': 'L', 'cnlQty': 160, 'uSec': '023246', 'classification': '0', 'mktPro': '0.00', 'ordEntTm': '24-Nov-2023 14:15:10', 'reqId': '1', 'algSeqNo': 'NA', 'qty': 160, 'unFldSz': 160, 'mktProPct': '--', 'algCat': 'NA', 'exOrdId': '1900000068166797', 'dscQty': 0, 'actId': 'YVZZ0', 'expDt': '28 Nov, 2023', 'trgPrc': '0.00', 'tok': '42495', 'symOrdId': 'NA', 'fldQty': 0, 'ordDtTm': '24-Nov-2023 14:22:52', 'avgPrc': '0.00', 'locId': '111111111111100', 'algId': 'NA', 'stat': 'Ok', 'prod': 'MIS', 'exSeg': 'nse_fo', 'GuiOrdId': '1700815510-630460-AKLPY0424H-ADMINAPI', 'usrId': 'AKLPY0424H', 'rptTp': 'NA', 'exCfmTm': '24-Nov-2023 14:22:52', 'hsUpTm': '2023/11/24 14:22:52', 'ordGenTp': 'NA', 'vldt': 'DAY', 'tckSz': '0.05', 'ordSt': 'cancell
# ...

# %%
# Position After Closing
pos_reportt = client.positions()
print(pos_reportt)
# Out:
# {'tid': 'server5_4239796', 'stat': 'Ok', 'stCode': 200, 'data': [{'buyAmt': '212.00', 'cfSellAmt': '0.00', 'prod': 'MIS', 'exSeg': 'nse_fo', 'sqrFlg': 'Y', 'actId': 'YVZZ0', 'cfBuyQty': '0', 'hsUpTm': '2023/11/24 14:22:45', 'cfSellQty': '0', 'tok': '42495', 'flBuyQty': '120', 'flSellQty': '120', 'sellAmt': '204.00', 'posFlg': 'true', 'cfBuyAmt': '0.00', 'stkPrc': '19300.00', 'trdSym': 'FINNIFTY23NOV19300PE', 'sym': 'FINNIFTY', 'multiplier': '1', 'precision': '2', 'expDt': '28 Nov, 2023', 'type': 'OPTIDX', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': 40, 'exp': '1701181800', 'lotSz': '40', 'optTp': 'PE', 'prcDen': '1'}]}

# %%
pos_reportt = client.positions()
print(pos_reportt)
# Out:
# {'tid': 'server5_4998918', 'stat': 'Ok', 'stCode': 200, 'data': [{'buyAmt': '2460.00', 'cfSellAmt': '0.00', 'prod': 'MIS', 'exSeg': 'nse_fo', 'sqrFlg': 'Y', 'actId': 'YVZZ0', 'cfBuyQty': '0', 'hsUpTm': '2023/11/29 14:10:17', 'cfSellQty': '0', 'tok': '58278', 'flBuyQty': '150', 'flSellQty': '0', 'sellAmt': '0.00', 'posFlg': 'true', 'cfBuyAmt': '0.00', 'stkPrc': '43800.00', 'trdSym': 'BANKNIFTY23NOV43800PE', 'sym': 'BANKNIFTY', 'multiplier': '1', 'precision': '2', 'expDt': '30 Nov, 2023', 'type': 'OPTIDX', 'genNum': '1', 'series': 'XX', 'prcNum': '1', 'genDen': '1', 'brdLtQty': 15, 'exp': '1701354600', 'lotSz': '15', 'optTp': 'PE', 'prcDen': '1'}]}
